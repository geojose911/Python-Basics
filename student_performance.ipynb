# %% [markdown]
# <a href="https://colab.research.google.com/github/geojose911/Python-Basics/blob/main/student_performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/StudentsPerformance.csv')
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
data.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
data['gender'].nunique()
# Out:
# 2

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['gender'] = le.fit_transform(data['gender'])
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0       0        group B           bachelor's degree      standard
# 1       0        group C                some college      standard
# 2       0        group B             master's degree      standard
# 3       1        group A          associate's degree  free/reduced
# 4       1        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data['race/ethnicity'].nunique()
# Out:
# 5

# %%
data['race/ethnicity']= le.fit_transform(data['race/ethnicity'])
data.head()
# Out:
#    gender  race/ethnicity parental level of education         lunch  \
# 0       0               1           bachelor's degree      standard
# 1       0               2                some college      standard
# 2       0               1             master's degree      standard
# 3       1               0          associate's degree  free/reduced
# 4       1               2                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data['parental level of education'].nunique()
# Out:
# 6

# %%
data['parental level of education']= le.fit_transform(data['parental level of education'])
data.head()
# Out:
#    gender  race/ethnicity  parental level of education         lunch  \
# 0       0               1                            1      standard
# 1       0               2                            4      standard
# 2       0               1                            3      standard
# 3       1               0                            0  free/reduced
# 4       1               2                            4      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data['lunch'].nunique()
# Out:
# 2

# %%
data['lunch']= le.fit_transform(data['lunch'])
data.head()
# Out:
#    gender  race/ethnicity  parental level of education  lunch  \
# 0       0               1                            1      1
# 1       0               2                            4      1
# 2       0               1                            3      1
# 3       1               0                            0      0
# 4       1               2                            4      1
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data['test preparation course'].nunique()
# Out:
# 2

# %%
data['test preparation course']= le.fit_transform(data['test preparation course'])
data.head()
# Out:
#    gender  race/ethnicity  parental level of education  lunch  \
# 0       0               1                            1      1
# 1       0               2                            4      1
# 2       0               1                            3      1
# 3       1               0                            0      0
# 4       1               2                            4      1
#
#    test preparation course  math score  reading score  writing score
# 0                        1          72             72             74
# 1                        0          69             90             88
# 2                        1          90             95             93
# 3                        1          47             57             44
# 4                        1          76             78             75
