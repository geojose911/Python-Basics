# %% [markdown]
# <a href="https://colab.research.google.com/github/geojose911/Python-Basics/blob/main/Even_No_From_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Given a list[10,19,18,20,5,6,7].Find only the even numbers

# %%
A=[10,19,18,20,5,6,7]
B=[]
for i in A:
  if i%2 == 0:
    B.append(i)
print(B)
# Out:
# [10, 18, 20, 6]
