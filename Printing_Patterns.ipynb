# %% [markdown]
# <a href="https://colab.research.google.com/github/geojose911/Python-Basics/blob/main/Printing_Patterns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Printing * Methods

# %%
print('*****')
print('****')
print('***')
print('**')
print('*')
# Out:
# *****
# ****
# ***
# **
# *

# %%
print('*' * 5)
print('*' * 4)
print('*' * 3)
print('*' * 2)
print('*' * 1)
# Out:
# *****
# ****
# ***
# **
# *

# %%
i = 5
print('*' * i)
i = 4
print('*' * i)
i = 3
print('*' * i)
i = 2
print('*' * i)
i = 1
print('*' * i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
i = 5
print('*' * i)
i = i - 1
print('*' * i)
i = i - 1
print('*' * i)
i = i - 1
print('*' * i)
i = i - 1
print('*' * i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
for i in range(5,1-1,-1):
  print('*' * i)
# Out:
# *****
# ****
# ***
# **
# *
