# %% [markdown]
# <a href="https://colab.research.google.com/github/geojose911/Python-Basics/blob/main/Python_Sample_works.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
r=int(input('Enter the radius of circle: '))
area= 3.14*r*r
print(area,'is the area')
# Out:
# Enter the radius of circle: 3
# 28.259999999999998 is the area

# %%
n=input('Enter name: ')
r=int(input('Enter roll.no: '))
m=float(input('ENter marks '))
print('Name is: ',n)
print('Roll.No is: ',r)
print('Mark is: ',m)
# Out:
# Enter name: Anisha
# Enter roll.no: 21
# ENter marks 78
# Name is:  Anisha
# Roll.No is:  21
# Mark is:  78.0

# %%
x=[12,3,47,10]
temp=x[0]
for i in x:
    if i>temp:
       temp=i
       print('Greatest is: ',i)
# Out:
# Greatest is:  47

# %%
for i in range(1,11):
    print('Previous: ',i-1)
    print('Current: ',i)
    sum = i+i-1
    print('Sum: ',sum)
# Out:
# Previous:  0
# Current:  1
# Sum:  1
# Previous:  1
# Current:  2
# Sum:  3
# Previous:  2
# Current:  3
# Sum:  5
# Previous:  3
# Current:  4
# Sum:  7
# Previous:  4
# Current:  5
# Sum:  9
# Previous:  5
# Current:  6
# Sum:  11
# Previous:  6
# Current:  7
# Sum:  13
# Previous:  7
# Current:  8
# Sum:  15
# Previous:  8
# Current:  9
# Sum:  17
# Previous:  9
# Current:  10
# Sum:  19

# %%
x=[10, 20,33,46,55]
for i in x:
    if i%5==0:
        print(i)
# Out:
# 10
# 20
# 55

# %%
p=int(input('Enter number: '))
if p<=1:
    print('Not prime')
else:
    for i in range(2,p):
        if p%i==0:
          print('Not prime')
          break
    else:
        print('Prime')
# Out:
# Enter number: 2
# Prime

# %%
x=[ 10,40,30,70 ]
for i in range(len(x)-1,-1,-1):
    print(x[i])
# Out:
# 70
# 30
# 40
# 10

# %%
for i in range(1,5):
    print('*'*i)
# Out:
# *
# **
# ***
# ****

# %%
a = float(input ('enter 1st: '))
b = float(input('enter 2nd: '))
c = float(input("enter 3rd: "))
if a>b and a>c:
  print(a,' is Maximum')
elif a<b and b>c:
  print(b,' is Maximum')
else:
  print(c,' is Maximum')
# Out:
# enter 1st: 2
# enter 2nd: 3
# enter 3rd: 4
# 4.0  is Maximum

# %%
for i in range(1,6):
    for j in range(i):
        print('*',end='')
    print()
for i in range(4,0,-1):
    for j in range(i):
        print('*',end='')
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *
